# %% [markdown]
# # YFinance Test
#
# In this test, we attempt to access fundamental stock data using yfinance python module

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
msft.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'exchange', 'timezone', 'shares', 'market_cap', 'last_price', 'previous_close', 'open', 'day_high', 'day_low', 'regular_market_previous_close', 'last_volume', 'fifty_day_average', 'two_hundred_day_average', 'ten_day_average_volume', 'three_month_average_volume', 'year_high', 'year_low', 'year_change']

# %%
#get historical data
hist = msft.history(period="1mo")
print(hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-02-21 00:00:00-05:00  254.479996  255.490005  251.589996  252.669998
# 2023-02-22 00:00:00-05:00  254.089996  254.339996  250.339996  251.509995
# 2023-02-23 00:00:00-05:00  255.559998  256.839996  250.479996  254.770004
# 2023-02-24 00:00:00-05:00  249.960007  251.000000  248.100006  249.220001
# 2023-02-27 00:00:00-05:00  252.460007  252.820007  249.389999  250.160004
# 2023-02-28 00:00:00-05:00  249.070007  251.490005  248.729996  249.419998
# 2023-03-01 00:00:00-05:00  250.759995  250.929993  245.789993  246.270004
# 2023-03-02 00:00:00-05:00  246.550003  251.399994  245.610001  251.110001
# 2023-03-03 00:00:00-05:00  252.190002  255.619995  251.389999  255.289993
# 2023-03-06 00:00:00-05:00  256.429993  260.119995  255.979996  256.869995
# 2023-03-07 00:00:00-05:00  256.299988  257.690002  253.389999  254.149994
# 2023-03-08 00:00:00-05:00  254.039993  254.539993  250.809998  253.699997
# ...

# %%
msft.income_stmt
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/4289892216.py in <module>
# ----> 1 msft.income_stmt
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in income_stmt(self)
#     160     @property
#     161     def income_stmt(self) -> _pd.DataFrame:
# --> 162         return self.get_income_stmt(pretty=True)
#     163
#     164     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1373             data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1374         else:
# -> 1375             data = self._fundamentals.financials.get_income_time_series(freq=freq, proxy=proxy)
#    1376
#    1377         if pretty:
#
# ...

# %%
msft.quarterly_income_stmt
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/3158211444.py in <module>
# ----> 1 msft.quarterly_income_stmt
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in quarterly_income_stmt(self)
#     164     @property
#     165     def quarterly_income_stmt(self) -> _pd.DataFrame:
# --> 166         return self.get_income_stmt(pretty=True, freq='quarterly')
#     167
#     168     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1373             data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1374         else:
# -> 1375             data = self._fundamentals.financials.get_income_time_series(freq=freq, proxy=proxy)
#    1376
#    1377         if pretty:
#
# ...

# %%
msft.balance_sheet
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/2948961734.py in <module>
# ----> 1 msft.balance_sheet
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in balance_sheet(self)
#     184     @property
#     185     def balance_sheet(self) -> _pd.DataFrame:
# --> 186         return self.get_balance_sheet(pretty=True)
#     187
#     188     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_balance_sheet(self, proxy, as_dict, pretty, freq, legacy)
#    1412             data = self._fundamentals.financials.get_balance_sheet_scrape(freq=freq, proxy=proxy)
#    1413         else:
# -> 1414             data = self._fundamentals.financials.get_balance_sheet_time_series(freq=freq, proxy=proxy)
#    1415
#    1416         if pretty:
#
# ...

# %%
msft.quarterly_balance_sheet
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/2118462344.py in <module>
# ----> 1 msft.quarterly_balance_sheet
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in quarterly_balance_sheet(self)
#     188     @property
#     189     def quarterly_balance_sheet(self) -> _pd.DataFrame:
# --> 190         return self.get_balance_sheet(pretty=True, freq='quarterly')
#     191
#     192     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_balance_sheet(self, proxy, as_dict, pretty, freq, legacy)
#    1412             data = self._fundamentals.financials.get_balance_sheet_scrape(freq=freq, proxy=proxy)
#    1413         else:
# -> 1414             data = self._fundamentals.financials.get_balance_sheet_time_series(freq=freq, proxy=proxy)
#    1415
# ...

# %%
msft.cashflow
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/1202646007.py in <module>
# ----> 1 msft.cashflow
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in cashflow(self)
#     208     @property
#     209     def cashflow(self) -> _pd.DataFrame:
# --> 210         return self.cash_flow
#     211
#     212     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in cash_flow(self)
#     200     @property
#     201     def cash_flow(self) -> _pd.DataFrame:
# --> 202         return self.get_cash_flow(pretty=True, freq="yearly")
#     203
#     204     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_cash_flow(self, proxy, as_dict, pretty, freq, legacy)
# ...

# %%
msft.quarterly_cashflow
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/3069526382.py in <module>
# ----> 1 msft.quarterly_cashflow
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in quarterly_cashflow(self)
#     212     @property
#     213     def quarterly_cashflow(self) -> _pd.DataFrame:
# --> 214         return self.quarterly_cash_flow
#     215
#     216     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in quarterly_cash_flow(self)
#     204     @property
#     205     def quarterly_cash_flow(self) -> _pd.DataFrame:
# --> 206         return self.get_cash_flow(pretty=True, freq='quarterly')
#     207
#     208     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_cash_flow(self, proxy, as_dict, pretty, freq, legacy)
# ...

# %%
msft.major_holders
# Out:
#         0                                      1
# 0   0.06%        % of Shares Held by All Insider
# 1  73.70%       % of Shares Held by Institutions
# 2  73.74%        % of Float Held by Institutions
# 3    6156  Number of Institutions Holding Shares

# %%
msft.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  642664898    2022-12-30  0.0863
# 1                     Blackrock Inc.  532042708    2022-12-30  0.0715
# 2           State Street Corporation  294574683    2022-12-30  0.0396
# 3                           FMR, LLC  198985661    2022-12-30  0.0267
# 4      Price (T.Rowe) Associates Inc  168647376    2022-12-30  0.0227
# 5      Geode Capital Management, LLC  142731177    2022-12-30  0.0192
# 6                     Morgan Stanley  119417954    2022-12-30  0.0160
# 7          JP Morgan Chase & Company   93021058    2022-12-30  0.0125
# 8            Capital World Investors   91715063    2022-12-30  0.0123
# 9  Norges Bank Investment Management   86316926    2022-12-30  0.0116
#
#           Value
# 0  174952672243
# 1  144837992244
# 2   80192069189
# 3   54169868680
# 4   45910877021
# 5   38855709882
# 6   32509150929
# 7   25323123641
# 8   24967592608
# 9   23498057713

# %%
msft.mutualfund_holders
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  222313847    2022-09-29
# 1                            Vanguard 500 Index Fund  169062762    2022-09-29
# 2                             SPDR S&P 500 ETF Trust   82250000    2022-12-30
# 3                            Fidelity 500 Index Fund   81679555    2022-12-30
# 4        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   76335623    2022-12-30
# 5                           iShares Core S&P 500 ETF   66940817    2022-12-30
# 6                         Vanguard Growth Index Fund   61426549    2022-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   54149972    2022-09-29
# 8                         Growth Fund Of America Inc   44491127    2022-12-30
# 9                 Select Sector SPDR Fund-Technology   34910084    2022-12-30
#
#     % Out        Value
# 0  0.0299  60520501011
# 1  0.0227  46023957556
# 2  0.0110  22390918403
# ...

# %%
msft.earnings
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/2289788410.py in <module>
# ----> 1 msft.earnings
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in earnings(self)
#     152     @property
#     153     def earnings(self) -> _pd.DataFrame:
# --> 154         return self.get_earnings()
#     155
#     156     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_earnings(self, proxy, as_dict, freq)
#    1341         """
#    1342         self._fundamentals.proxy = proxy
# -> 1343         data = self._fundamentals.earnings[freq]
#    1344         if as_dict:
#    1345             dict_data = data.to_dict()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/scrapers/fundamentals.py in earnings(self)
#      32     def earnings(self) -> dict:
# ...

# %%
msft.quarterly_earnings
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.sustainability

# %%
print(msft.recommendations)
# Out:
# None

# %%
msft.recommendations_summary

# %%
msft.analyst_price_target
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hn/vdq8ffhj0zq9blr74w80pr180000gn/T/ipykernel_1508/1338008655.py in <module>
# ----> 1 msft.analyst_price_target
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in analyst_price_target(self)
#     220     @property
#     221     def analyst_price_target(self) -> _pd.DataFrame:
# --> 222         return self.get_analyst_price_target()
#     223
#     224     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_analyst_price_target(self, proxy, as_dict)
#    1294     def get_analyst_price_target(self, proxy=None, as_dict=False):
#    1295         self._analysis.proxy = proxy
# -> 1296         data = self._analysis.analyst_price_target
#    1297         if as_dict:
#    1298             return data.to_dict()
#
# ...

# %%
msft.revenue_forecasts

# %%
msft.earnings_forecasts

# %%
msft.earnings_trend

# %%
msft.calendar

# %%
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-01-22 16:00:00-05:00           NaN           NaN          NaN
# 2024-01-22 05:00:00-05:00           NaN           NaN          NaN
# 2023-10-23 06:00:00-04:00           NaN           NaN          NaN
# 2023-07-24 06:00:00-04:00           NaN           NaN          NaN
# 2023-04-24 06:00:00-04:00          2.23           NaN          NaN
# 2023-01-24 11:00:00-05:00          2.30          2.32       0.0109
# 2022-10-25 12:00:00-04:00          2.30          2.35       0.0204
# 2022-07-26 12:00:00-04:00          2.29          2.23      -0.0275
# 2022-04-26 12:00:00-04:00          2.19          2.22       0.0160
# 2022-01-25 11:00:00-05:00          2.31          2.48       0.0727
# 2021-10-26 12:00:00-04:00          2.08          2.27       0.0940
# 2021-07-27 12:00:00-04:00          1.92          2.17       0.1326

# %%
msft.options  #shows options expirations
# Out:
# ('2023-03-24',
#  '2023-03-31',
#  '2023-04-06',
#  '2023-04-14',
#  '2023-04-21',
#  '2023-04-28',
#  '2023-05-19',
#  '2023-06-16',
#  '2023-07-21',
#  '2023-08-18',
#  '2023-09-15',
#  '2023-10-20',
#  '2023-11-17',
#  '2024-01-19',
#  '2024-06-21',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-06-20',
#  '2025-12-19')

# %%
msft.news
# Out:
# [{'uuid': '102ad6bc-311b-32b1-819f-637c095740d0',
#   'title': 'Microsoft Says It Wants To Launch App Store Rival',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/102ad6bc-311b-32b1-819f-637c095740d0/microsoft-says-it-wants-to.html',
#   'providerPublishTime': 1679356831,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/QuewPQ6td5cT5ThncwgKcw--~B/aD01MzM7dz03OTk7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/fa4568c0ccf72a9914d4c6d51873961e',
#      'width': 799,
#      'height': 533,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/dsfHHm0hI_nwn4qCgHUzfA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/fa4568c0ccf72a9914d4c6d51873961e',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'AAPL', 'GOOGL']},
#  {'uuid': 'e0a009e2-caaa-3815-874a-799027e35569',
# ...

# %%
opt = msft.option_chain("2023-03-24")  #gets option chain for specified expiration date
print(opt)
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   MSFT230324C00150000 2023-03-20 13:35:56+00:00   150.0     125.05   0.0
# 1   MSFT230324C00155000 2023-03-20 13:43:40+00:00   155.0     119.05   0.0
# 2   MSFT230324C00160000 2023-03-20 13:48:50+00:00   160.0     113.25   0.0
# 3   MSFT230324C00165000 2023-02-03 20:17:26+00:00   165.0      93.60  89.1
# 4   MSFT230324C00170000 2023-03-20 15:20:34+00:00   170.0     102.55   0.0
# 5   MSFT230324C00180000 2023-02-17 16:43:30+00:00   180.0      76.28  97.0
# 6   MSFT230324C00190000 2023-02-13 17:57:08+00:00   190.0      82.18  73.5
# 7   MSFT230324C00195000 2023-03-01 15:22:06+00:00   195.0      53.55   0.0
# 8   MSFT230324C00200000 2023-03-10 20:14:19+00:00   200.0      49.55   0.0
# 9   MSFT230324C00205000 2023-03-17 17:34:03+00:00   205.0      75.10   0.0
# 10  MSFT230324C00207500 2023-03-15 16:45:36+00:00   207.5      55.00   0.0
# ...
